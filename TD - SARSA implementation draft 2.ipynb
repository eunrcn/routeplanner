# %%
import numpy as np
import random

# %% [markdown]
# Additional data to set up our environment

# %%
possible_actions = { # k:v. original state: [lst of possible next states]
            "S1": ["S2", "S6", "S10"],
            "S2": ["S1", "S6", "S7", "S3", "S11"],
            "S3": ["S2", "S7", "S8", "S4"],
            "S4": ["S3", "S8", "S9", "S5"],
            "S5": ["S4", "S9", "S14"],
            "S6": ["S1", "S2", "S10", "S11", "S7"],
            "S7": ["S2", "S3", "S8", "S12", "S11", "S6"],
            "S8": ["S3", "S4", "S7", "S9", "S12", "S13"],
            "S9": ["S4", "S5", "S8", "S13", "S14"],
            "S10": ["S1", "S6", "S11"],
            "S11": ["S10", "S6", "S2", "S7", "S12"],
            "S12": ["S11", "S7", "S8", "S13"],
            "S13": ["S12", "S8", "S9", "S14"],
            "S14": ["S13", "S9", "S5"]
        }

################################################################################################
# Add weather score to states 
################################################################################################

# Weather exposure lookup dictionary
weather_exposure = {
    (1, 2): 95, (1, 6): 1, (1, 10): 1,
    (2, 1): 95, (2, 6): 5, (2, 7): 90, (2, 3): 44, (2, 11): 32,
    (3, 2): 44, (3, 7): 57, (3, 8): 9, (3, 4): 41,
    (4, 3): 41, (4, 8): 54, (4, 9): 50, (4, 5): 65,
    (5, 4): 65, (5, 9): 9, (5, 14): 52,
    (6, 1): 1, (6, 2): 5, (6, 10): 27, (6, 11): 50, (6, 7): 82,
    (7, 2): 90, (7, 3): 57, (7, 8): 51, (7, 12): 33, (7, 11): 27, (7, 6): 82,
    (8, 3): 9, (8, 4): 54, (8, 7): 51, (8, 9): 84, (8, 12): 36, (8, 13): 22,
    (9, 4): 50, (9, 5): 9, (9, 8): 84, (9, 13): 31, (9, 14): 39,
    (10, 1): 1, (10, 6): 27, (10, 11): 52,
    (11, 10): 52, (11, 6): 50, (11, 2): 32, (11, 7): 27, (11, 12): 18,
    (12, 11): 18, (12, 7): 33, (12, 8): 36, (12, 13): 46,
    (13, 12): 46, (13, 8): 22, (13, 9): 31, (13, 14): 80,
    (14, 13): 80, (14, 9): 39, (14, 5): 52
}

# Assign weather exposure scores for each action
weather_scores = {
    state: {action: weather_exposure.get((int(state[1:]), int(action[1:])), 1000)
            for action in neighbors}
    for state, neighbors in possible_actions.items()
}

# O(1) lookup for weather score
# define the state and action to retrieve the weather score
state, action = "S3", "S8"
weather_score = weather_scores[state][action]

################################################################################################
# Add safety score to states
################################################################################################

# Safety exposure lookup dictionary
safety_exposure = {
    (1, 2): 22, (1, 6): 13, (1, 10): 15,
    (2, 1): 22, (2, 6): 19, (2, 7): 36, (2, 3): 41, (2,11): 21,
    (3, 2): 41, (3, 7): 36, (3, 8): 42, (3, 4): 48,
    (4, 3): 48, (4, 8): 42, (4, 9): 62, (4, 5): 66,
    (5, 4): 66, (5, 9): 99, (5, 14): 99,
    (6, 1): 13, (6, 2): 19, (6, 10): 0, (6, 11): 18, (6, 7): 21,
    (7, 2): 36, (7, 3): 36, (7, 8): 38, (7, 12): 39, (7, 11): 18, (7, 6): 21,
    (8, 3): 42, (8, 4): 42, (8, 7): 38, (8, 9): 64, (8, 12): 58, (8, 13): 69,
    (9, 4): 62, (9, 5): 99, (9, 8): 64, (9, 13): 58, (9, 14): 99,
    (10, 1): 15, (10, 6): 0, (10, 11): 1,
    (11, 10): 1, (11, 6): 18, (11, 2): 21, (11, 7): 18, (11, 12): 46,
    (12, 11): 46, (12, 7): 39, (12, 8): 58, (12, 13): 69,
    (13, 12): 69, (13, 8): 69, (13, 9): 58, (13, 14): 99,
    (14, 13): 99, (14, 9): 99, (14, 5): 99
}

# Assign safety scores for each action
safety_scores = {
    state: {action: safety_exposure.get((int(state[1:]), int(action[1:])), 1000)
            for action in neighbors}
    for state, neighbors in possible_actions.items()
}

# O(1) lookup for safety score
# define the state and action to retrieve the safety score
state, action = "S3", "S8"
safety_score = safety_scores[state][action]

################################################################################################
# Add travel time score to states
################################################################################################

# Travel Time lookup dictionary
travel_time = {
    (1, 2): 20, (1, 6): 80, (1, 10): 100,
    (2, 1): 20, (2, 6): 60, (2, 7): 60, (2, 3): 40, (2, 11): 100,
    (3, 2): 40, (3, 7): 60, (3, 8): 60, (3, 4): 20,
    (4, 3): 20, (4, 8): 60, (4, 9): 60, (4, 5): 20,
    (5, 4): 20, (5, 9): 60, (5, 14): 100,
    (6, 1): 80, (6, 2): 60, (6, 10): 60, (6, 11): 40, (6, 7): 20,
    (7, 2): 60, (7, 3): 60, (7, 8): 20, (7, 12): 60, (7, 11): 60, (7, 6): 20,
    (8, 3): 60, (8, 4): 60, (8, 7): 20, (8, 9): 20, (8, 12): 60, (8, 13): 40,
    (9, 4): 60, (9, 5): 60, (9, 8): 20, (9, 13): 60, (9, 14): 60,
    (10, 1): 100, (10, 6): 60, (10, 11): 20,
    (11, 10): 20, (11, 6): 40, (11, 2): 100, (11, 7): 60, (11, 12): 20,
    (12, 11): 20, (12, 7): 60, (12, 8): 60, (12, 13): 20,
    (13, 12): 20, (13, 8): 40, (13, 9): 60, (13, 14): 20,
    (14, 13): 20, (14, 9): 60, (14, 5): 100
}

# Assign travel time scores for each action
travel_time_scores = {
    state: {action: travel_time.get((int(state[1:]), int(action[1:])), 1000)
            for action in neighbors}
    for state, neighbors in possible_actions.items()
}

# O(1) lookup for travel time score
# define the state and action to retrieve the travel time score
state, action = "S3", "S8"
travel_time_score = travel_time_scores[state][action]

# %% [markdown]
# Setting up our environment class

# %%
class PedestrianPaths:
    def __init__(self, weather, safety, travel):
        self.state = "S1"  # Start state
        self.goal = "S14"
        self.num_states = 14
        self.possible_actions = { # k:v. original state: [lst of possible next states]
            "S1": ["S2", "S6", "S10"],
            "S2": ["S1", "S6", "S7", "S3", "S11"],
            "S3": ["S2", "S7", "S8", "S4"],
            "S4": ["S3", "S8", "S9", "S5"],
            "S5": ["S4", "S9", "S14"],
            "S6": ["S1", "S2", "S10", "S11", "S7"],
            "S7": ["S2", "S3", "S8", "S12", "S11", "S6"],
            "S8": ["S3", "S4", "S7", "S9", "S12", "S13"],
            "S9": ["S4", "S5", "S8", "S13", "S14"],
            "S10": ["S1", "S6", "S11"],
            "S11": ["S10", "S6", "S2", "S7", "S12"],
            "S12": ["S11", "S7", "S8", "S13"],
            "S13": ["S12", "S8", "S9", "S14"],
            "S14": ["S13", "S9", "S5"]
        }
        self.transition_probabilities = {
            "S1": 0.6,
            "S2": 0.6,
            "S3": 0.6,
            "S4": 0.6,
            "S5": 0.6,
            "S6": 0.7,
            "S7": 0.7,
            "S8": 0.7,
            "S9": 0.7,
            "S10": 0.7,
            "S11": 0.8,
            "S12": 0.8,
            "S13": 0.9,
            "S14": 0.9
        }
        self.weather = weather
        self.safety = safety
        self.travel = travel
        # Define the normalization ranges (assuming max and min possible values for each score type)
        self.WEATHER_MAX = 1000
        self.SAFETY_MAX = 1000
        self.TRAVEL_TIME_MAX = 1000
        # Define the weights for each score (adjust based on their importance)
        self.WEATHER_WEIGHT = 0.3
        self.SAFETY_WEIGHT = 0.4
        self.TRAVEL_TIME_WEIGHT = 0.3

    def step(self, action): #str -> (str, int, bool) #simple since deterministic action
        """ Move in the environment based on action """
        probability = self.transition_probabilities[action]
        if random.random() < probability: #successfully found the way to this state
            self.state = action
        #else, got lost and remain in the same state
        
        # Define rewards
        reward = 1 if self.state == self.goal else -0.3
        done = self.state == self.goal  # Episode ends when goal is reached
        return self.state, reward, done

    def reset(self): # _ -> str
        self.state = "S1"
        return self.state
    
################################################################################################
# Functions to dynamically calculate the reward based on the state and action, using the scores (also based on the (weather, safety, travel time) weights depending on what user prioritizes most?)
################################################################################################
    def normalize_score(self, score, max_score): #int,int -> int
        """ Normalize the score based on the maximum score for each category. """
        return score / max_score


    def calculate_reward(self, state, action, weather_weight, safety_weight, travel_time_weight): # -> int
        """ 
        Smarter reward function that considers normalized scores and weighted importance. 
        Incorporates dynamic scaling for weather, safety, and travel time.
        """

        # Retrieve individual scores
        weather_score = self.weather_scores[state][action]
        safety_score = self.safety_scores[state][action]
        travel_time_score = self.travel_time_scores[state][action]

        # Normalize the scores to be between 0 and 1
        normalized_weather = self.normalize_score(weather_score, self.WEATHER_MAX)
        normalized_safety = self.normalize_score(safety_score, self.SAFETY_MAX)
        normalized_travel_time = self.normalize_score(
            travel_time_score, self.TRAVEL_TIME_MAX)

        # Calculate weighted sum of normalized scores
        total_score = (self.WEATHER_WEIGHT * normalized_weather +
                    self.SAFETY_WEIGHT * normalized_safety +
                    self.TRAVEL_TIME_WEIGHT * normalized_travel_time)

        # Reward is the negative of the total score (since higher scores should be worse)
        reward = -1 * total_score

        return reward

env = PedestrianPaths(weather_scores, safety_scores, travel_time_scores)

# %% [markdown]
# Setting up our RL agent class

# %%
state_size = 14
action_size = 14 

class SARSAAgent:
    def __init__(self, env, state_size, action_size, alpha=0.1, gamma=0.99, epsilon=0.1):
        self.state_size = state_size
        self.action_size = action_size
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.q_table = np.full((state_size, action_size), float('-inf'))  # Q-value table instantiate all as impossible actions first
        self.env = env

        #certain values in the q_table for select few states that can be reached from each state
        curr_state = 0
        for lst_next_state in env.possible_actions.values():
            for next_state in lst_next_state:
                state_index = int(next_state[1:])-1
                self.q_table[curr_state][state_index] = 0 #instantiate to 0 for all possible actions
            curr_state+=1
            if curr_state == self.state_size:
                break

    def choose_action(self, state): #str -> str
        """ Epsilon-greedy policy for action selection """
        # if random.random() < self.epsilon:
        #     return random.choice(self.env.possible_actions[state])  
        # else:
        state_index = int(state[1:])-1
        return "S" + str(np.argmax(self.q_table[state_index])+1)  # Exploit

    def update(self, state, action, reward, next_state, next_action):
        """ SARSA Q-value update rule. On-Policy """
        state_index = int(state[1:])-1
        action_index = int(action[1:])-1
        next_state_index = int(next_state[1:])-1
        next_action_index = int(next_action[1:])-1
        td_target = reward + self.gamma * self.q_table[next_state_index, next_action_index]
        td_error = td_target - self.q_table[state_index, action_index]
        self.q_table[state_index, action_index] += self.alpha * td_error  # Update rule

agent = SARSAAgent(env, state_size, action_size)

# %% [markdown]
# Training RL agent

# %%
env = PedestrianPaths(weather_scores, safety_scores, travel_time_scores)
agent = SARSAAgent(env, state_size, action_size)

episodes = 1000
for episode in range(episodes):
    state = env.reset()
    action = agent.choose_action(state) #first action to choose
    while True:
        
        next_state, reward, done = env.step(action)
        next_action = agent.choose_action(next_state) if not done else None

        if done:
            break
        
        # Update Q-table using SARSA
        agent.update(state, action, reward, next_state, next_action if not done else 0)
        
        state, action = next_state, next_action        

    # Print learned Q-values
    print(agent.q_table)
# Out:
# [[       -inf -0.1112187         -inf        -inf        -inf -0.08427
#          -inf        -inf        -inf -0.05997           -inf        -inf
#          -inf        -inf]
#  [-0.11685606        -inf -0.086943          -inf        -inf -0.0813
#   -0.11418573        -inf        -inf        -inf -0.089616          -inf
#          -inf        -inf]
#  [       -inf -0.05997           -inf -0.086943          -inf        -inf
#   -0.05997    -0.086943          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.089616   -0.062643          -inf        -inf        -inf        -inf
#   -0.057             -inf        -inf -0.062643   -0.035643          -inf
#          -inf        -inf]
#  [       -inf -0.086943   -0.086943          -inf        -inf -0.083973
#          -inf -0.03              -inf        -inf -0.03297    -0.057
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.05997           -inf        -inf
#   -0.03              -inf -0.03              -inf        -inf -0.03
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.1138917         -inf        -inf        -inf        -inf -0.057
#          -inf        -inf        -inf        -inf -0.083973          -inf
#          -inf        -inf]
#  [       -inf -0.05997           -inf        -inf        -inf -0.1112187
#   -0.057             -inf        -inf -0.057             -inf -0.057
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.05997    -0.03              -inf        -inf -0.03297           -inf
#   -0.03              -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.1112187         -inf        -inf        -inf -0.08427
#          -inf        -inf        -inf -0.11656203        -inf        -inf
#          -inf        -inf]
#  [-0.11685606        -inf -0.086943          -inf        -inf -0.0813
#   -0.11418573        -inf        -inf        -inf -0.089616          -inf
#          -inf        -inf]
#  [       -inf -0.05997           -inf -0.086943          -inf        -inf
#   -0.05997    -0.086943          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.089616   -0.062643          -inf        -inf        -inf        -inf
#   -0.057             -inf        -inf -0.062643   -0.0677217         -inf
#          -inf        -inf]
#  [       -inf -0.086943   -0.086943          -inf        -inf -0.083973
#          -inf -0.05997           -inf        -inf -0.065316   -0.057
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.05997           -inf        -inf
#   -0.08723703        -inf -0.057             -inf        -inf -0.03
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.1138917         -inf        -inf        -inf        -inf -0.08482866
#          -inf        -inf        -inf        -inf -0.1112187         -inf
#          -inf        -inf]
#  [       -inf -0.05997           -inf        -inf        -inf -0.1112187
#   -0.1112187         -inf        -inf -0.08961333        -inf -0.1112187
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.05997    -0.05997           -inf        -inf -0.03297           -inf
#   -0.03              -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.14140122        -inf        -inf        -inf -0.111486
#          -inf        -inf        -inf -0.11656203        -inf        -inf
#          -inf        -inf]
#  [-0.11685606        -inf -0.16560142        -inf        -inf -0.16420804
#   -0.11418573        -inf        -inf        -inf -0.11952612        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.086943          -inf        -inf
#   -0.089616   -0.086943          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12166505 -0.12137102        -inf        -inf        -inf        -inf
#   -0.11445036        -inf        -inf -0.09477674 -0.09688656        -inf
#          -inf        -inf]
#  [       -inf -0.086943   -0.086943          -inf        -inf -0.083973
#          -inf -0.05997           -inf        -inf -0.065316   -0.08427
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.05997           -inf        -inf
#   -0.08723703        -inf -0.057             -inf        -inf -0.03
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.1138917         -inf        -inf        -inf        -inf -0.11305024
#          -inf        -inf        -inf        -inf -0.13926229        -inf
#          -inf        -inf]
#  [       -inf -0.12415012        -inf        -inf        -inf -0.1112187
#   -0.1112187         -inf        -inf -0.12166265        -inf -0.1112187
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.05997    -0.05997           -inf        -inf -0.03297           -inf
#   -0.057             -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.14140122        -inf        -inf        -inf -0.16661996
#          -inf        -inf        -inf -0.11656203        -inf        -inf
#          -inf        -inf]
#  [-0.11685606        -inf -0.16560142        -inf        -inf -0.16420804
#   -0.11418573        -inf        -inf        -inf -0.11952612        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.086943          -inf        -inf
#   -0.089616   -0.086943          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12166505 -0.12137102        -inf        -inf        -inf        -inf
#   -0.16583935        -inf        -inf -0.12649104 -0.12820856        -inf
#          -inf        -inf]
#  [       -inf -0.086943   -0.086943          -inf        -inf -0.083973
#          -inf -0.11388903        -inf        -inf -0.09979505 -0.08427
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.05997           -inf        -inf
#   -0.08723703        -inf -0.057             -inf        -inf -0.08723703
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.1138917         -inf        -inf        -inf        -inf -0.14133699
#          -inf        -inf        -inf        -inf -0.13926229        -inf
#          -inf        -inf]
#  [       -inf -0.12415012        -inf        -inf        -inf -0.16832732
#   -0.13656311        -inf        -inf -0.12166265        -inf -0.13573983
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.05997    -0.05997           -inf        -inf -0.09765398        -inf
#   -0.0813            -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.16856548        -inf        -inf        -inf -0.19197369
#          -inf        -inf        -inf -0.1730762         -inf        -inf
#          -inf        -inf]
#  [-0.17856066        -inf -0.16560142        -inf        -inf -0.16420804
#   -0.16557979        -inf        -inf        -inf -0.14961811        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.086943          -inf        -inf
#   -0.089616   -0.086943          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12166505 -0.151067          -inf        -inf        -inf        -inf
#   -0.16583935        -inf        -inf -0.12649104 -0.12820856        -inf
#          -inf        -inf]
#  [       -inf -0.1467392  -0.14505016        -inf        -inf -0.14084285
#          -inf -0.11388903        -inf        -inf -0.13325379 -0.13870419
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.05997           -inf        -inf
#   -0.08723703        -inf -0.057             -inf        -inf -0.08723703
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.14650125        -inf        -inf        -inf        -inf -0.14133699
#          -inf        -inf        -inf        -inf -0.16762692        -inf
#          -inf        -inf]
#  [       -inf -0.15570207        -inf        -inf        -inf -0.16832732
#   -0.13656311        -inf        -inf -0.18017385        -inf -0.18498071
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.09258036 -0.11896773        -inf        -inf -0.09765398        -inf
#   -0.10317           -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.19652113        -inf        -inf        -inf -0.21546897
#          -inf        -inf        -inf -0.22660517        -inf        -inf
#          -inf        -inf]
#  [-0.17856066        -inf -0.16560142        -inf        -inf -0.18983208
#   -0.19029683        -inf        -inf        -inf -0.17817605        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.086943          -inf        -inf
#   -0.089616   -0.086943          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.15663309 -0.1823527         -inf        -inf        -inf        -inf
#   -0.16583935        -inf        -inf -0.18523172 -0.1620521         -inf
#          -inf        -inf]
#  [       -inf -0.1467392  -0.14505016        -inf        -inf -0.14084285
#          -inf -0.13547012        -inf        -inf -0.13325379 -0.13870419
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.05997           -inf        -inf
#   -0.08723703        -inf -0.057             -inf        -inf -0.08723703
#   -0.057             -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.18085652        -inf        -inf        -inf        -inf -0.1965987
#          -inf        -inf        -inf        -inf -0.16762692        -inf
#          -inf        -inf]
#  [       -inf -0.21324833        -inf        -inf        -inf -0.19645022
#   -0.1951984         -inf        -inf -0.18017385        -inf -0.18498071
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.09258036 -0.11896773        -inf        -inf -0.09765398        -inf
#   -0.10317           -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.22326356        -inf        -inf        -inf -0.21546897
#          -inf        -inf        -inf -0.22660517        -inf        -inf
#          -inf        -inf]
#  [-0.17856066        -inf -0.21449959        -inf        -inf -0.18983208
#   -0.19029683        -inf        -inf        -inf -0.17817605        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.1112187         -inf        -inf
#   -0.089616   -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.062643   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.15663309 -0.1823527         -inf        -inf        -inf        -inf
#   -0.16583935        -inf        -inf -0.18523172 -0.1620521         -inf
#          -inf        -inf]
#  [       -inf -0.1467392  -0.14505016        -inf        -inf -0.14084285
#          -inf -0.13547012        -inf        -inf -0.13325379 -0.13870419
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.05997           -inf        -inf
#   -0.08723703        -inf -0.0813            -inf        -inf -0.08723703
#   -0.057             -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.18085652        -inf        -inf        -inf        -inf -0.1965987
#          -inf        -inf        -inf        -inf -0.16762692        -inf
#          -inf        -inf]
#  [       -inf -0.21324833        -inf        -inf        -inf -0.19645022
#   -0.1951984         -inf        -inf -0.18017385        -inf -0.18498071
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.09258036 -0.11896773        -inf        -inf -0.09765398        -inf
#   -0.10317           -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.22326356        -inf        -inf        -inf -0.26623483
#          -inf        -inf        -inf -0.22660517        -inf        -inf
#          -inf        -inf]
#  [-0.17856066        -inf -0.21449959        -inf        -inf -0.18983208
#   -0.19029683        -inf        -inf        -inf -0.17817605        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.1112187         -inf        -inf
#   -0.089616   -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.062643   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.21387197 -0.1823527         -inf        -inf        -inf        -inf
#   -0.16583935        -inf        -inf -0.18523172 -0.19368411        -inf
#          -inf        -inf]
#  [       -inf -0.1467392  -0.14505016        -inf        -inf -0.14084285
#          -inf -0.15756611        -inf        -inf -0.16925305 -0.13870419
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.05997           -inf        -inf
#   -0.08723703        -inf -0.0813            -inf        -inf -0.08723703
#   -0.0813            -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.18085652        -inf        -inf        -inf        -inf -0.1965987
#          -inf        -inf        -inf        -inf -0.19917732        -inf
#          -inf        -inf]
#  [       -inf -0.21324833        -inf        -inf        -inf -0.19645022
#   -0.24591442        -inf        -inf -0.20875153        -inf -0.2056481
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12651445 -0.11896773        -inf        -inf -0.09765398        -inf
#   -0.10317           -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.24857663        -inf        -inf        -inf -0.26623483
#          -inf        -inf        -inf -0.22660517        -inf        -inf
#          -inf        -inf]
#  [-0.17856066        -inf -0.21449959        -inf        -inf -0.18983208
#   -0.19029683        -inf        -inf        -inf -0.20980701        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.1112187         -inf        -inf
#   -0.089616   -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.057             -inf
#          -inf -0.062643   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.21387197 -0.1823527         -inf        -inf        -inf        -inf
#   -0.19298713        -inf        -inf -0.18523172 -0.19368411        -inf
#          -inf        -inf]
#  [       -inf -0.1467392  -0.14505016        -inf        -inf -0.14084285
#          -inf -0.15756611        -inf        -inf -0.16925305 -0.16450151
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.05997           -inf        -inf
#   -0.08723703        -inf -0.0813            -inf        -inf -0.08723703
#   -0.0813            -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.18085652        -inf        -inf        -inf        -inf -0.1965987
#          -inf        -inf        -inf        -inf -0.19917732        -inf
#          -inf        -inf]
#  [       -inf -0.21324833        -inf        -inf        -inf -0.22322329
#   -0.24591442        -inf        -inf -0.20875153        -inf -0.22529712
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12651445 -0.11896773        -inf        -inf -0.16515985        -inf
#   -0.125823          -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.27139647        -inf        -inf        -inf -0.26623483
#          -inf        -inf        -inf -0.27612777        -inf        -inf
#          -inf        -inf]
#  [-0.21563769        -inf -0.23192162        -inf        -inf -0.21918681
#   -0.21521059        -inf        -inf        -inf -0.26687295        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.1112187         -inf        -inf
#   -0.12625345 -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.21387197 -0.21291081        -inf        -inf        -inf        -inf
#   -0.24487469        -inf        -inf -0.2164271  -0.19368411        -inf
#          -inf        -inf]
#  [       -inf -0.18283618 -0.20194178        -inf        -inf -0.17586429
#          -inf -0.21495334        -inf        -inf -0.16925305 -0.18982917
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.08723703        -inf -0.0813            -inf        -inf -0.08723703
#   -0.0813            -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.21737996        -inf        -inf        -inf        -inf -0.22499174
#          -inf        -inf        -inf        -inf -0.22992599        -inf
#          -inf        -inf]
#  [       -inf -0.24076288        -inf        -inf        -inf -0.22322329
#   -0.24591442        -inf        -inf -0.26580009        -inf -0.22529712
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12651445 -0.14300798        -inf        -inf -0.16515985        -inf
#   -0.125823          -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.27139647        -inf        -inf        -inf -0.31554646
#          -inf        -inf        -inf -0.27612777        -inf        -inf
#          -inf        -inf]
#  [-0.21563769        -inf -0.23192162        -inf        -inf -0.21918681
#   -0.24044558        -inf        -inf        -inf -0.26687295        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.1112187         -inf        -inf
#   -0.12625345 -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.21387197 -0.24292558        -inf        -inf        -inf        -inf
#   -0.24487469        -inf        -inf -0.2164271  -0.2264148         -inf
#          -inf        -inf]
#  [       -inf -0.18283618 -0.20194178        -inf        -inf -0.17586429
#          -inf -0.21495334        -inf        -inf -0.20463216 -0.18982917
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.08723703        -inf -0.0813            -inf        -inf -0.08723703
#   -0.0813            -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.21737996        -inf        -inf        -inf        -inf -0.22499174
#          -inf        -inf        -inf        -inf -0.22992599        -inf
#          -inf        -inf]
#  [       -inf -0.24076288        -inf        -inf        -inf -0.25197913
#   -0.24591442        -inf        -inf -0.26580009        -inf -0.24522388
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12651445 -0.14300798        -inf        -inf -0.16515985        -inf
#   -0.1462107         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.31774395        -inf        -inf        -inf -0.31554646
#          -inf        -inf        -inf -0.3490362         -inf        -inf
#          -inf        -inf]
#  [-0.25141057        -inf -0.27653138        -inf        -inf -0.27524418
#   -0.24044558        -inf        -inf        -inf -0.26687295        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.2521883  -0.24292558        -inf        -inf        -inf        -inf
#   -0.24487469        -inf        -inf -0.24754706 -0.2264148         -inf
#          -inf        -inf]
#  [       -inf -0.18283618 -0.20194178        -inf        -inf -0.17586429
#          -inf -0.21495334        -inf        -inf -0.20463216 -0.18982917
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.08723703        -inf -0.0813            -inf        -inf -0.08723703
#   -0.0813            -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.28171121        -inf        -inf        -inf        -inf -0.25391885
#          -inf        -inf        -inf        -inf -0.28756198        -inf
#          -inf        -inf]
#  [       -inf -0.26964683        -inf        -inf        -inf -0.25197913
#   -0.24591442        -inf        -inf -0.26580009        -inf -0.24522388
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12651445 -0.14300798        -inf        -inf -0.16515985        -inf
#   -0.1462107         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.34238998        -inf        -inf        -inf -0.36312289
#          -inf        -inf        -inf -0.3490362         -inf        -inf
#          -inf        -inf]
#  [-0.31449989        -inf -0.27653138        -inf        -inf -0.27524418
#   -0.2912854         -inf        -inf        -inf -0.29453118        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.2521883  -0.27243713        -inf        -inf        -inf        -inf
#   -0.24487469        -inf        -inf -0.24754706 -0.25805048        -inf
#          -inf        -inf]
#  [       -inf -0.24627765 -0.20194178        -inf        -inf -0.2123275
#          -inf -0.21495334        -inf        -inf -0.20463216 -0.21500404
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.08723703        -inf -0.10614           -inf        -inf -0.08723703
#   -0.10614           -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.28171121        -inf        -inf        -inf        -inf -0.25391885
#          -inf        -inf        -inf        -inf -0.28756198        -inf
#          -inf        -inf]
#  [       -inf -0.26964683        -inf        -inf        -inf -0.25197913
#   -0.27011607        -inf        -inf -0.26580009        -inf -0.26322642
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.16127357 -0.16675589        -inf        -inf -0.16515985        -inf
#   -0.1462107         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.392092          -inf        -inf        -inf -0.3823576
#          -inf        -inf        -inf -0.37202199        -inf        -inf
#          -inf        -inf]
#  [-0.31449989        -inf -0.27653138        -inf        -inf -0.30196236
#   -0.2912854         -inf        -inf        -inf -0.29453118        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.1138917         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.29152405 -0.27243713        -inf        -inf        -inf        -inf
#   -0.27037946        -inf        -inf -0.30470753 -0.28830485        -inf
#          -inf        -inf]
#  [       -inf -0.24627765 -0.25882444        -inf        -inf -0.2123275
#          -inf -0.21495334        -inf        -inf -0.23911488 -0.21500404
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.08723703        -inf -0.10614           -inf        -inf -0.08723703
#   -0.10614           -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.31948925        -inf        -inf        -inf        -inf -0.31026508
#          -inf        -inf        -inf        -inf -0.28756198        -inf
#          -inf        -inf]
#  [       -inf -0.26964683        -inf        -inf        -inf -0.3080616
#   -0.27011607        -inf        -inf -0.26580009        -inf -0.28137864
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.16127357 -0.16675589        -inf        -inf -0.16515985        -inf
#   -0.16455963        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.392092          -inf        -inf        -inf -0.3823576
#          -inf        -inf        -inf -0.39328843        -inf        -inf
#          -inf        -inf]
#  [-0.31449989        -inf -0.29015352        -inf        -inf -0.30196236
#   -0.2912854         -inf        -inf        -inf -0.29453118        -inf
#          -inf        -inf]
#  [       -inf -0.11979101        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.141139          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.29152405 -0.30257002        -inf        -inf        -inf        -inf
#   -0.29436193        -inf        -inf -0.30470753 -0.28830485        -inf
#          -inf        -inf]
#  [       -inf -0.24627765 -0.25882444        -inf        -inf -0.24806602
#          -inf -0.26077241        -inf        -inf -0.23911488 -0.21500404
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.14407128        -inf -0.128496          -inf        -inf -0.12447941
#   -0.10614           -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.05997    -0.03      ]
#  [-0.31948925        -inf        -inf        -inf        -inf -0.33600614
#          -inf        -inf        -inf        -inf -0.31511999        -inf
#          -inf        -inf]
#  [       -inf -0.26964683        -inf        -inf        -inf -0.3080616
#   -0.27011607        -inf        -inf -0.29993632        -inf -0.28137864
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.19642659 -0.16675589        -inf        -inf -0.16515985        -inf
#   -0.16455963        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.392092          -inf        -inf        -inf -0.40266402
#          -inf        -inf        -inf -0.39328843        -inf        -inf
#          -inf        -inf]
#  [-0.31449989        -inf -0.30299748        -inf        -inf -0.30196236
#   -0.34018011        -inf        -inf        -inf -0.29453118        -inf
#          -inf        -inf]
#  [       -inf -0.16664916        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.141139          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.29152405 -0.30257002        -inf        -inf        -inf        -inf
#   -0.29436193        -inf        -inf -0.30470753 -0.3161694         -inf
#          -inf        -inf]
#  [       -inf -0.24627765 -0.25882444        -inf        -inf -0.24806602
#          -inf -0.26077241        -inf        -inf -0.23911488 -0.23979504
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.14407128        -inf -0.128496          -inf        -inf -0.12447941
#   -0.10614           -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.05997    -0.03      ]
#  [-0.31948925        -inf        -inf        -inf        -inf -0.33600614
#          -inf        -inf        -inf        -inf -0.31511999        -inf
#          -inf        -inf]
#  [       -inf -0.30140735        -inf        -inf        -inf -0.3080616
#   -0.27011607        -inf        -inf -0.29993632        -inf -0.28137864
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.19642659 -0.16675589        -inf        -inf -0.16515985        -inf
#   -0.18107367        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.41204139        -inf        -inf        -inf -0.40266402
#          -inf        -inf        -inf -0.39328843        -inf        -inf
#          -inf        -inf]
#  [-0.31449989        -inf -0.30299748        -inf        -inf -0.30196236
#   -0.34018011        -inf        -inf        -inf -0.32181955        -inf
#          -inf        -inf]
#  [       -inf -0.16664916        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.141139          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.29152405 -0.30257002        -inf        -inf        -inf        -inf
#   -0.29436193        -inf        -inf -0.30470753 -0.3161694         -inf
#          -inf        -inf]
#  [       -inf -0.24627765 -0.25882444        -inf        -inf -0.24806602
#          -inf -0.26077241        -inf        -inf -0.27305988 -0.26232437
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.14407128        -inf -0.128496          -inf        -inf -0.12447941
#   -0.10614           -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.05997    -0.03      ]
#  [-0.31948925        -inf        -inf        -inf        -inf -0.33600614
#          -inf        -inf        -inf        -inf -0.31511999        -inf
#          -inf        -inf]
#  [       -inf -0.30140735        -inf        -inf        -inf -0.3080616
#   -0.32083886        -inf        -inf -0.29993632        -inf -0.2995916
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.19642659 -0.22485651        -inf        -inf -0.20802477        -inf
#   -0.1959363         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.41204139        -inf        -inf        -inf -0.40266402
#          -inf        -inf        -inf -0.41515646        -inf        -inf
#          -inf        -inf]
#  [-0.31449989        -inf -0.30299748        -inf        -inf -0.30196236
#   -0.34018011        -inf        -inf        -inf -0.32181955        -inf
#          -inf        -inf]
#  [       -inf -0.16664916        -inf -0.13573983        -inf        -inf
#   -0.12625345 -0.141139          -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.29152405 -0.30257002        -inf        -inf        -inf        -inf
#   -0.29436193        -inf        -inf -0.30470753 -0.3161694         -inf
#          -inf        -inf]
#  [       -inf -0.24627765 -0.25882444        -inf        -inf -0.24806602
#          -inf -0.26077241        -inf        -inf -0.27305988 -0.26232437
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.14407128        -inf -0.128496          -inf        -inf -0.12447941
#   -0.10614           -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.05997    -0.03      ]
#  [-0.31948925        -inf        -inf        -inf        -inf -0.33600614
#          -inf        -inf        -inf        -inf -0.34326756        -inf
#          -inf        -inf]
#  [       -inf -0.30140735        -inf        -inf        -inf -0.3080616
#   -0.32083886        -inf        -inf -0.29993632        -inf -0.31903014
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.19642659 -0.22485651        -inf        -inf -0.20802477        -inf
#   -0.20931267        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.45736069        -inf        -inf        -inf -0.43929869
#          -inf        -inf        -inf -0.43527025        -inf        -inf
#          -inf        -inf]
#  [-0.35415039        -inf -0.34192412        -inf        -inf -0.33090796
#   -0.34018011        -inf        -inf        -inf -0.3501357         -inf
#          -inf        -inf]
#  [       -inf -0.16664916        -inf -0.19301644        -inf        -inf
#   -0.16818664 -0.16753296        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.062643   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.35990137 -0.33344851        -inf        -inf        -inf        -inf
#   -0.3460423         -inf        -inf -0.33750138 -0.34613645        -inf
#          -inf        -inf]
#  [       -inf -0.28164664 -0.3031473         -inf        -inf -0.28321385
#          -inf -0.26077241        -inf        -inf -0.27305988 -0.26232437
#          -inf        -inf]
#  [       -inf        -inf -0.11685606 -0.11656203        -inf        -inf
#   -0.14407128        -inf -0.128496          -inf        -inf -0.12447941
#   -0.15540047        -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.05997    -0.03      ]
#  [-0.41649192        -inf        -inf        -inf        -inf -0.39308661
#          -inf        -inf        -inf        -inf -0.39161038        -inf
#          -inf        -inf]
#  [       -inf -0.33312675        -inf        -inf        -inf -0.33855621
#   -0.32083886        -inf        -inf -0.36223799        -inf -0.33657335
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.25923077 -0.22485651        -inf        -inf -0.20802477        -inf
#   -0.20931267        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.057      -0.057             -inf        -inf -0.03297
#          -inf -0.03      ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.45736069        -inf        -inf        -inf -0.43929869
#          -inf        -inf        -inf -0.46051266        -inf        -inf
#          -inf        -inf]
#  [-0.35415039        -inf -0.35431747        -inf        -inf -0.36082856
#   -0.38882605        -inf        -inf        -inf -0.3501357         -inf
#          -inf        -inf]
#  [       -inf -0.23959415        -inf -0.19301644        -inf        -inf
#   -0.16818664 -0.19310312        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.086943          -inf -0.0813            -inf
#          -inf -0.12489107 -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf -0.03              -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.35990137 -0.36378149        -inf        -inf        -inf        -inf
#   -0.3460423         -inf        -inf -0.33750138 -0.34613645        -inf
#          -inf        -inf]
#  [       -inf -0.28164664 -0.3031473         -inf        -inf -0.28321385
#          -inf -0.27623481        -inf        -inf -0.27305988 -0.31345029
#          -inf        -inf]
#  [       -inf        -inf -0.15166872 -0.14110748        -inf        -inf
#   -0.14407128        -inf -0.128496          -inf        -inf -0.16275342
#   -0.15540047        -inf]
#  [       -inf        -inf        -inf -0.057      -0.057             -inf
#          -inf -0.0650487         -inf        -inf        -inf        -inf
#   -0.05997    -0.03      ]
# ...
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.39709997        -inf        -inf -1.41386569
#   -1.40896016        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.55014399        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.46912554        -inf        -inf        -inf -2.63418067
#          -inf        -inf        -inf -2.60323059        -inf        -inf
#          -inf        -inf]
#  [-2.13814872        -inf -2.07059271        -inf        -inf -2.10996546
#   -2.08784388        -inf        -inf        -inf -2.10104425        -inf
#          -inf        -inf]
#  [       -inf -1.64434904        -inf -1.59629657        -inf        -inf
#   -1.68926493 -1.64770407        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.27438592        -inf -1.16280491        -inf
#          -inf -1.23996064 -1.27692531        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.8315511         -inf        -inf
#          -inf        -inf -0.83428293        -inf        -inf        -inf
#          -inf -0.79694765]
#  [-2.31647684 -2.31748814        -inf        -inf        -inf        -inf
#   -2.30490643        -inf        -inf -2.30011613 -2.24636442        -inf
#          -inf        -inf]
#  [       -inf -1.90334181 -1.90370109        -inf        -inf -1.90377186
#          -inf -1.93235275        -inf        -inf -1.91159192 -1.91217875
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.39709997        -inf        -inf -1.41386569
#   -1.40896016        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.55014399        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.48197945        -inf        -inf        -inf -2.63418067
#          -inf        -inf        -inf -2.60323059        -inf        -inf
#          -inf        -inf]
#  [-2.13814872        -inf -2.07670326        -inf        -inf -2.10996546
#   -2.08784388        -inf        -inf        -inf -2.10104425        -inf
#          -inf        -inf]
#  [       -inf -1.64434904        -inf -1.60734793        -inf        -inf
#   -1.68926493 -1.64770407        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.27438592        -inf -1.15542224        -inf
#          -inf -1.23996064 -1.27692531        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.8315511         -inf        -inf
#          -inf        -inf -0.83428293        -inf        -inf        -inf
#          -inf -0.79694765]
#  [-2.31647684 -2.31748814        -inf        -inf        -inf        -inf
#   -2.30490643        -inf        -inf -2.30011613 -2.24636442        -inf
#          -inf        -inf]
#  [       -inf -1.90334181 -1.90370109        -inf        -inf -1.90377186
#          -inf -1.93235275        -inf        -inf -1.91159192 -1.91217875
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.39709997        -inf        -inf -1.41386569
#   -1.40896016        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.55014399        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.46937513        -inf        -inf        -inf -2.63418067
#          -inf        -inf        -inf -2.60323059        -inf        -inf
#          -inf        -inf]
#  [-2.13814872        -inf -2.08329135        -inf        -inf -2.10996546
#   -2.08784388        -inf        -inf        -inf -2.10104425        -inf
#          -inf        -inf]
#  [       -inf -1.64434904        -inf -1.59099994        -inf        -inf
#   -1.68926493 -1.64770407        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.27438592        -inf -1.14877783        -inf
#          -inf -1.23996064 -1.27692531        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.8315511         -inf        -inf
#          -inf        -inf -0.83428293        -inf        -inf        -inf
#          -inf -0.79694765]
#  [-2.31647684 -2.31748814        -inf        -inf        -inf        -inf
#   -2.30490643        -inf        -inf -2.30011613 -2.24636442        -inf
#          -inf        -inf]
#  [       -inf -1.90334181 -1.90370109        -inf        -inf -1.90377186
#          -inf -1.93235275        -inf        -inf -1.91159192 -1.91217875
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.39709997        -inf        -inf -1.41386569
#   -1.40896016        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.55014399        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.45868346        -inf        -inf        -inf -2.63418067
#          -inf        -inf        -inf -2.60323059        -inf        -inf
#          -inf        -inf]
#  [-2.13814872        -inf -2.07195932        -inf        -inf -2.10996546
#   -2.08784388        -inf        -inf        -inf -2.10104425        -inf
#          -inf        -inf]
#  [       -inf -1.71658617        -inf -1.67580114        -inf        -inf
#   -1.68926493 -1.65124656        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.27438592        -inf -1.14877783        -inf
#          -inf -1.23996064 -1.27692531        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.8315511         -inf        -inf
#          -inf        -inf -0.83428293        -inf        -inf        -inf
#          -inf -0.79694765]
#  [-2.31647684 -2.31748814        -inf        -inf        -inf        -inf
#   -2.30490643        -inf        -inf -2.30011613 -2.24636442        -inf
#          -inf        -inf]
#  [       -inf -1.90334181 -1.90370109        -inf        -inf -1.90377186
#          -inf -1.93235275        -inf        -inf -1.91159192 -1.91217875
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.45261964        -inf        -inf -1.41386569
#   -1.41984011        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.55014399        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.44793909        -inf        -inf        -inf -2.63418067
#          -inf        -inf        -inf -2.60323059        -inf        -inf
#          -inf        -inf]
#  [-2.13814872        -inf -2.0582368         -inf        -inf -2.10996546
#   -2.08784388        -inf        -inf        -inf -2.10104425        -inf
#          -inf        -inf]
#  [       -inf -1.71658617        -inf -1.67580114        -inf        -inf
#   -1.68926493 -1.6560946         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.27438592        -inf -1.14877783        -inf
#          -inf -1.23996064 -1.27692531        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.8315511         -inf        -inf
#          -inf        -inf -0.83428293        -inf        -inf        -inf
#          -inf -0.79694765]
#  [-2.31647684 -2.31748814        -inf        -inf        -inf        -inf
#   -2.30490643        -inf        -inf -2.30011613 -2.24636442        -inf
#          -inf        -inf]
#  [       -inf -1.90334181 -1.90370109        -inf        -inf -1.90377186
#          -inf -1.93235275        -inf        -inf -1.91159192 -1.91217875
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.45261964        -inf        -inf -1.4816709
#   -1.41984011        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.54690556        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.43691062        -inf        -inf        -inf -2.63418067
#          -inf        -inf        -inf -2.60323059        -inf        -inf
#          -inf        -inf]
#  [-2.13814872        -inf -2.07151407        -inf        -inf -2.10996546
#   -2.08784388        -inf        -inf        -inf -2.10104425        -inf
#          -inf        -inf]
#  [       -inf -1.71658617        -inf -1.65195003        -inf        -inf
#   -1.68926493 -1.71189897        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.27438592        -inf -1.16876396        -inf
#          -inf -1.23996064 -1.27692531        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.8315511         -inf        -inf
#          -inf        -inf -0.83428293        -inf        -inf        -inf
#          -inf -0.79694765]
#  [-2.31647684 -2.31748814        -inf        -inf        -inf        -inf
#   -2.30490643        -inf        -inf -2.30011613 -2.24636442        -inf
#          -inf        -inf]
#  [       -inf -1.90334181 -1.90370109        -inf        -inf -1.90377186
#          -inf -1.93235275        -inf        -inf -1.91159192 -1.91217875
#          -inf        -inf]
#  [       -inf        -inf -1.41769879 -1.42343153        -inf        -inf
#   -1.48368797        -inf -1.45261964        -inf        -inf -1.4816709
#   -1.41984011        -inf]
#  [       -inf        -inf        -inf -1.0566594  -1.04499824        -inf
#          -inf -1.03057912        -inf        -inf        -inf        -inf
#   -1.04840274 -1.02979171]
#  [-2.29715878        -inf        -inf        -inf        -inf -2.26441231
#          -inf        -inf        -inf        -inf -2.25800517        -inf
#          -inf        -inf]
#  [       -inf -2.04090531        -inf        -inf        -inf -2.04349533
#   -2.02508118        -inf        -inf -2.03260463        -inf -1.91767969
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.57294182 -1.62220803        -inf        -inf -1.63474045        -inf
#   -1.54690556        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.25496369 -1.23028587        -inf        -inf -1.24908439
#          -inf -1.23006031]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
