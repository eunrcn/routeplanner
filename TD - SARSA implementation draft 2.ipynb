# %%
import numpy as np
import random

# %% [markdown]
# Additional data to set up our environment

# %%
possible_actions = { # k:v. original state: [lst of possible next states]
            "S1": ["S2", "S6", "S10"],
            "S2": ["S1", "S6", "S7", "S3", "S11"],
            "S3": ["S2", "S7", "S8", "S4"],
            "S4": ["S3", "S8", "S9", "S5"],
            "S5": ["S4", "S9", "S14"],
            "S6": ["S1", "S2", "S10", "S11", "S7"],
            "S7": ["S2", "S3", "S8", "S12", "S11", "S6"],
            "S8": ["S3", "S4", "S7", "S9", "S12", "S13"],
            "S9": ["S4", "S5", "S8", "S13", "S14"],
            "S10": ["S1", "S6", "S11"],
            "S11": ["S10", "S6", "S2", "S7", "S12"],
            "S12": ["S11", "S7", "S8", "S13"],
            "S13": ["S12", "S8", "S9", "S14"],
            "S14": ["S13", "S9", "S5"]
        }

################################################################################################
# Add weather score to states 
################################################################################################

# Weather exposure lookup dictionary
weather_exposure = {
    (1, 2): 95, (1, 6): 1, (1, 10): 1,
    (2, 1): 95, (2, 6): 5, (2, 7): 90, (2, 3): 44, (2, 11): 32,
    (3, 2): 44, (3, 7): 57, (3, 8): 9, (3, 4): 41,
    (4, 3): 41, (4, 8): 54, (4, 9): 50, (4, 5): 65,
    (5, 4): 65, (5, 9): 9, (5, 14): 52,
    (6, 1): 1, (6, 2): 5, (6, 10): 27, (6, 11): 50, (6, 7): 82,
    (7, 2): 90, (7, 3): 57, (7, 8): 51, (7, 12): 33, (7, 11): 27, (7, 6): 82,
    (8, 3): 9, (8, 4): 54, (8, 7): 51, (8, 9): 84, (8, 12): 36, (8, 13): 22,
    (9, 4): 50, (9, 5): 9, (9, 8): 84, (9, 13): 31, (9, 14): 39,
    (10, 1): 1, (10, 6): 27, (10, 11): 52,
    (11, 10): 52, (11, 6): 50, (11, 2): 32, (11, 7): 27, (11, 12): 18,
    (12, 11): 18, (12, 7): 33, (12, 8): 36, (12, 13): 46,
    (13, 12): 46, (13, 8): 22, (13, 9): 31, (13, 14): 80,
    (14, 13): 80, (14, 9): 39, (14, 5): 52
}

# Assign weather exposure scores for each action
weather_scores = {
    state: {action: weather_exposure.get((int(state[1:]), int(action[1:])), 1000)
            for action in neighbors}
    for state, neighbors in possible_actions.items()
}

# O(1) lookup for weather score
# define the state and action to retrieve the weather score
state, action = "S3", "S8"
weather_score = weather_scores[state][action]

################################################################################################
# Add safety score to states
################################################################################################

# Safety exposure lookup dictionary
safety_exposure = {
    (1, 2): 22, (1, 6): 13, (1, 10): 15,
    (2, 1): 22, (2, 6): 19, (2, 7): 36, (2, 3): 41, (2,11): 21,
    (3, 2): 41, (3, 7): 36, (3, 8): 42, (3, 4): 48,
    (4, 3): 48, (4, 8): 42, (4, 9): 62, (4, 5): 66,
    (5, 4): 66, (5, 9): 99, (5, 14): 99,
    (6, 1): 13, (6, 2): 19, (6, 10): 0, (6, 11): 18, (6, 7): 21,
    (7, 2): 36, (7, 3): 36, (7, 8): 38, (7, 12): 39, (7, 11): 18, (7, 6): 21,
    (8, 3): 42, (8, 4): 42, (8, 7): 38, (8, 9): 64, (8, 12): 58, (8, 13): 69,
    (9, 4): 62, (9, 5): 99, (9, 8): 64, (9, 13): 58, (9, 14): 99,
    (10, 1): 15, (10, 6): 0, (10, 11): 1,
    (11, 10): 1, (11, 6): 18, (11, 2): 21, (11, 7): 18, (11, 12): 46,
    (12, 11): 46, (12, 7): 39, (12, 8): 58, (12, 13): 69,
    (13, 12): 69, (13, 8): 69, (13, 9): 58, (13, 14): 99,
    (14, 13): 99, (14, 9): 99, (14, 5): 99
}

# Assign safety scores for each action
safety_scores = {
    state: {action: safety_exposure.get((int(state[1:]), int(action[1:])), 1000)
            for action in neighbors}
    for state, neighbors in possible_actions.items()
}

# O(1) lookup for safety score
# define the state and action to retrieve the safety score
state, action = "S3", "S8"
safety_score = safety_scores[state][action]

################################################################################################
# Add travel time score to states
################################################################################################

# Travel Time lookup dictionary
travel_time = {
    (1, 2): 20, (1, 6): 80, (1, 10): 100,
    (2, 1): 20, (2, 6): 60, (2, 7): 60, (2, 3): 40, (2, 11): 100,
    (3, 2): 40, (3, 7): 60, (3, 8): 60, (3, 4): 20,
    (4, 3): 20, (4, 8): 60, (4, 9): 60, (4, 5): 20,
    (5, 4): 20, (5, 9): 60, (5, 14): 100,
    (6, 1): 80, (6, 2): 60, (6, 10): 60, (6, 11): 40, (6, 7): 20,
    (7, 2): 60, (7, 3): 60, (7, 8): 20, (7, 12): 60, (7, 11): 60, (7, 6): 20,
    (8, 3): 60, (8, 4): 60, (8, 7): 20, (8, 9): 20, (8, 12): 60, (8, 13): 40,
    (9, 4): 60, (9, 5): 60, (9, 8): 20, (9, 13): 60, (9, 14): 60,
    (10, 1): 100, (10, 6): 60, (10, 11): 20,
    (11, 10): 20, (11, 6): 40, (11, 2): 100, (11, 7): 60, (11, 12): 20,
    (12, 11): 20, (12, 7): 60, (12, 8): 60, (12, 13): 20,
    (13, 12): 20, (13, 8): 40, (13, 9): 60, (13, 14): 20,
    (14, 13): 20, (14, 9): 60, (14, 5): 100
}

# Assign travel time scores for each action
travel_time_scores = {
    state: {action: travel_time.get((int(state[1:]), int(action[1:])), 1000)
            for action in neighbors}
    for state, neighbors in possible_actions.items()
}

# O(1) lookup for travel time score
# define the state and action to retrieve the travel time score
state, action = "S3", "S8"
travel_time_score = travel_time_scores[state][action]

# %% [markdown]
# Setting up our environment class

# %%
class PedestrianPaths:
    def __init__(self, weather, safety, travel):
        self.state = "S1"  # Start state
        self.goal = "S14"
        self.num_states = 14
        self.possible_actions = { # k:v. original state: [lst of possible next states]
            "S1": ["S2", "S6", "S10"],
            "S2": ["S1", "S6", "S7", "S3", "S11"],
            "S3": ["S2", "S7", "S8", "S4"],
            "S4": ["S3", "S8", "S9", "S5"],
            "S5": ["S4", "S9", "S14"],
            "S6": ["S1", "S2", "S10", "S11", "S7"],
            "S7": ["S2", "S3", "S8", "S12", "S11", "S6"],
            "S8": ["S3", "S4", "S7", "S9", "S12", "S13"],
            "S9": ["S4", "S5", "S8", "S13", "S14"],
            "S10": ["S1", "S6", "S11"],
            "S11": ["S10", "S6", "S2", "S7", "S12"],
            "S12": ["S11", "S7", "S8", "S13"],
            "S13": ["S12", "S8", "S9", "S14"],
            "S14": ["S13", "S9", "S5"]
        }
        self.transition_probabilities = {
            "S1": 0.6,
            "S2": 0.6,
            "S3": 0.6,
            "S4": 0.6,
            "S5": 0.6,
            "S6": 0.7,
            "S7": 0.7,
            "S8": 0.7,
            "S9": 0.7,
            "S10": 0.7,
            "S11": 0.8,
            "S12": 0.8,
            "S13": 0.9,
            "S14": 0.9
        }
        self.weather = weather
        self.safety = safety
        self.travel = travel
        # Define the normalization ranges (assuming max and min possible values for each score type)
        self.WEATHER_MAX = 1000
        self.SAFETY_MAX = 1000
        self.TRAVEL_TIME_MAX = 1000
        # Define the weights for each score (adjust based on their importance)
        self.WEATHER_WEIGHT = 0.3
        self.SAFETY_WEIGHT = 0.4
        self.TRAVEL_TIME_WEIGHT = 0.3

    def step(self, action): #str -> (str, int, bool) #simple since deterministic action
        """ Move in the environment based on action """
        probability = self.transition_probabilities[action]
        if random.random() < probability: #successfully found the way to this state
            self.state = action
        #else, got lost and remain in the same state
        
        # Define rewards
        reward = 1 if self.state == self.goal else -0.3
        done = self.state == self.goal  # Episode ends when goal is reached
        return self.state, reward, done

    def reset(self): # _ -> str
        self.state = "S1"
        return self.state
    
################################################################################################
# Functions to dynamically calculate the reward based on the state and action, using the scores (also based on the (weather, safety, travel time) weights depending on what user prioritizes most?)
################################################################################################
    def normalize_score(self, score, max_score): #int,int -> int
        """ Normalize the score based on the maximum score for each category. """
        return score / max_score


    def calculate_reward(self, state, action, weather_weight, safety_weight, travel_time_weight): # -> int
        """ 
        Smarter reward function that considers normalized scores and weighted importance. 
        Incorporates dynamic scaling for weather, safety, and travel time.
        """

        # Retrieve individual scores
        weather_score = self.weather_scores[state][action]
        safety_score = self.safety_scores[state][action]
        travel_time_score = self.travel_time_scores[state][action]

        # Normalize the scores to be between 0 and 1
        normalized_weather = self.normalize_score(weather_score, self.WEATHER_MAX)
        normalized_safety = self.normalize_score(safety_score, self.SAFETY_MAX)
        normalized_travel_time = self.normalize_score(
            travel_time_score, self.TRAVEL_TIME_MAX)

        # Calculate weighted sum of normalized scores
        total_score = (self.WEATHER_WEIGHT * normalized_weather +
                    self.SAFETY_WEIGHT * normalized_safety +
                    self.TRAVEL_TIME_WEIGHT * normalized_travel_time)

        # Reward is the negative of the total score (since higher scores should be worse)
        reward = -1 * total_score

        return reward

env = PedestrianPaths(weather_scores, safety_scores, travel_time_scores)

# %% [markdown]
# Setting up our RL agent class

# %%
state_size = 14
action_size = 14 

class SARSAAgent:
    def __init__(self, env, state_size, action_size, alpha=0.1, gamma=0.99, epsilon=0.1):
        self.state_size = state_size
        self.action_size = action_size
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.q_table = np.full((state_size, action_size), float('-inf'))  # Q-value table instantiate all as impossible actions first
        self.env = env

        #certain values in the q_table for select few states that can be reached from each state
        curr_state = 0
        for lst_next_state in env.possible_actions.values():
            for next_state in lst_next_state:
                state_index = int(next_state[1:])-1
                self.q_table[curr_state][state_index] = 0 #instantiate to 0 for all possible actions
            curr_state+=1
            if curr_state == self.state_size:
                break

    def choose_action(self, state): #str -> str
        """ Epsilon-greedy policy for action selection """
        if random.random() < self.epsilon:
            return random.choice(self.env.possible_actions[state]) # Explore
        else:
            state_index = int(state[1:])-1
            return "S" + str(np.argmax(self.q_table[state_index])+1)  # Exploit

    def update(self, state, action, reward, next_state, next_action):
        """ SARSA Q-value update rule. On-Policy """
        state_index = int(state[1:])-1
        action_index = int(action[1:])-1
        next_state_index = int(next_state[1:])-1
        next_action_index = int(next_action[1:])-1
        td_target = reward + self.gamma * self.q_table[next_state_index, next_action_index]
        td_error = td_target - self.q_table[state_index, action_index]
        self.q_table[state_index, action_index] += self.alpha * td_error  # Update rule

agent = SARSAAgent(env, state_size, action_size)

# %% [markdown]
# Training RL agent

# %%
env = PedestrianPaths(weather_scores, safety_scores, travel_time_scores)
agent = SARSAAgent(env, state_size, action_size)

episodes = 1000
for episode in range(episodes):
    state = env.reset()
    action = agent.choose_action(state) #first action to choose
    while True:
        
        next_state, reward, done = env.step(action)
        next_action = agent.choose_action(next_state) if not done else None

        if done:
            break
        
        # Update Q-table using SARSA
        agent.update(state, action, reward, next_state, next_action if not done else 0)
        
        state, action = next_state, next_action        

    # Print learned Q-values
    print(agent.q_table)
# Out:
# [[       -inf -0.057             -inf        -inf        -inf -0.03
#          -inf        -inf        -inf -0.03              -inf        -inf
#          -inf        -inf]
#  [-0.057             -inf -0.083973          -inf        -inf -0.03
#   -0.03              -inf        -inf        -inf -0.03              -inf
#          -inf        -inf]
#  [       -inf -0.057             -inf -0.057             -inf        -inf
#   -0.057      -0.05997           -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.057             -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf  0.                -inf        -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.06296614 -0.05993763        -inf        -inf        -inf        -inf
#   -0.057             -inf        -inf  0.         -0.03              -inf
#          -inf        -inf]
#  [       -inf -0.05997    -0.057             -inf        -inf -0.03
#          -inf -0.057             -inf        -inf -0.03       -0.03
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.08427           -inf        -inf
#   -0.089616          -inf -0.057             -inf        -inf -0.03
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.03              -inf        -inf        -inf        -inf  0.
#          -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf]
#  [       -inf -0.057             -inf        -inf        -inf -0.057
#   -0.03              -inf        -inf  0.                -inf  0.
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.03297    -0.03              -inf        -inf  0.                -inf
#    0.                -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf  0.
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.08427           -inf        -inf        -inf -0.11418573
#          -inf        -inf        -inf -0.08991003        -inf        -inf
#          -inf        -inf]
#  [-0.086943          -inf -0.083973          -inf        -inf -0.06293383
#   -0.086943          -inf        -inf        -inf -0.062643          -inf
#          -inf        -inf]
#  [       -inf -0.086943          -inf -0.057             -inf        -inf
#   -0.057      -0.05997           -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.057             -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf  0.                -inf        -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12192618 -0.08691386        -inf        -inf        -inf        -inf
#   -0.086943          -inf        -inf -0.11151273 -0.11715267        -inf
#          -inf        -inf]
#  [       -inf -0.05997    -0.086943          -inf        -inf -0.05997
#          -inf -0.057             -inf        -inf -0.089616   -0.057
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.08427           -inf        -inf
#   -0.089616          -inf -0.057             -inf        -inf -0.05997
#   -0.03              -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.11656203        -inf        -inf        -inf        -inf -0.065316
#          -inf        -inf        -inf        -inf -0.09498365        -inf
#          -inf        -inf]
#  [       -inf -0.13603386        -inf        -inf        -inf -0.08723703
#   -0.05997           -inf        -inf -0.06293703        -inf -0.057
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.03297    -0.05997           -inf        -inf -0.03326403        -inf
#   -0.083973          -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.11204466        -inf        -inf        -inf -0.11418573
#          -inf        -inf        -inf -0.08991003        -inf        -inf
#          -inf        -inf]
#  [-0.086943          -inf -0.083973          -inf        -inf -0.06293383
#   -0.086943          -inf        -inf        -inf -0.0920217         -inf
#          -inf        -inf]
#  [       -inf -0.086943          -inf -0.057             -inf        -inf
#   -0.057      -0.05997           -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.057             -inf -0.057             -inf
#          -inf -0.03       -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf  0.                -inf        -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12192618 -0.08691386        -inf        -inf        -inf        -inf
#   -0.086943          -inf        -inf -0.11151273 -0.11715267        -inf
#          -inf        -inf]
#  [       -inf -0.05997    -0.086943          -inf        -inf -0.05997
#          -inf -0.08427           -inf        -inf -0.089616   -0.057
#          -inf        -inf]
#  [       -inf        -inf -0.057      -0.08427           -inf        -inf
#   -0.089616          -inf -0.057             -inf        -inf -0.05997
#   -0.057             -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.11656203        -inf        -inf        -inf        -inf -0.065316
#          -inf        -inf        -inf        -inf -0.09498365        -inf
#          -inf        -inf]
#  [       -inf -0.13603386        -inf        -inf        -inf -0.08723703
#   -0.05997           -inf        -inf -0.06293703        -inf -0.08456403
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.065316   -0.05997           -inf        -inf -0.03326403        -inf
#   -0.083973          -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.11204466        -inf        -inf        -inf -0.11418573
#          -inf        -inf        -inf -0.11738531        -inf        -inf
#          -inf        -inf]
#  [-0.086943          -inf -0.083973          -inf        -inf -0.09823856
#   -0.086943          -inf        -inf        -inf -0.0920217         -inf
#          -inf        -inf]
#  [       -inf -0.086943          -inf -0.1112187         -inf        -inf
#   -0.057      -0.05997           -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.057             -inf -0.057             -inf
#          -inf -0.089616   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf  0.                -inf        -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12192618 -0.11445293        -inf        -inf        -inf        -inf
#   -0.086943          -inf        -inf -0.13976484 -0.14380925        -inf
#          -inf        -inf]
#  [       -inf -0.05997    -0.086943          -inf        -inf -0.05997
#          -inf -0.08427           -inf        -inf -0.089616   -0.11154184
#          -inf        -inf]
#  [       -inf        -inf -0.086943   -0.08427           -inf        -inf
#   -0.089616          -inf -0.1138917         -inf        -inf -0.05997
#   -0.0813            -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.11656203        -inf        -inf        -inf        -inf -0.12844622
#          -inf        -inf        -inf        -inf -0.12142232        -inf
#          -inf        -inf]
#  [       -inf -0.13603386        -inf        -inf        -inf -0.08723703
#   -0.089616          -inf        -inf -0.09652592        -inf -0.11204466
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.065316   -0.11656203        -inf        -inf -0.06616839        -inf
#   -0.083973          -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.13915352        -inf        -inf        -inf -0.11418573
#          -inf        -inf        -inf -0.11738531        -inf        -inf
#          -inf        -inf]
#  [-0.086943          -inf -0.1112187         -inf        -inf -0.09823856
#   -0.11418573        -inf        -inf        -inf -0.0920217         -inf
#          -inf        -inf]
#  [       -inf -0.086943          -inf -0.1112187         -inf        -inf
#   -0.08723703 -0.0920217         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.057             -inf -0.057             -inf
#          -inf -0.089616   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf  0.                -inf        -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.12192618 -0.11445293        -inf        -inf        -inf        -inf
#   -0.11659143        -inf        -inf -0.13976484 -0.14380925        -inf
#          -inf        -inf]
#  [       -inf -0.09258036 -0.11418573        -inf        -inf -0.11952638
#          -inf -0.11178003        -inf        -inf -0.089616   -0.11154184
#          -inf        -inf]
#  [       -inf        -inf -0.086943   -0.08427           -inf        -inf
#   -0.089616          -inf -0.1138917         -inf        -inf -0.09043928
#   -0.10317           -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.11656203        -inf        -inf        -inf        -inf -0.12844622
#          -inf        -inf        -inf        -inf -0.12142232        -inf
#          -inf        -inf]
#  [       -inf -0.13603386        -inf        -inf        -inf -0.08723703
#   -0.089616          -inf        -inf -0.09652592        -inf -0.11204466
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12433297 -0.11656203        -inf        -inf -0.06616839        -inf
#   -0.083973          -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.21226924        -inf        -inf        -inf -0.2018428
#          -inf        -inf        -inf -0.21040755        -inf        -inf
#          -inf        -inf]
#  [-0.15668899        -inf -0.13870419        -inf        -inf -0.1595634
#   -0.1438098         -inf        -inf        -inf -0.15061478        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.1112187         -inf        -inf
#   -0.08723703 -0.0920217         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.057             -inf -0.057             -inf
#          -inf -0.089616   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf  0.                -inf        -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#          -inf  0.        ]
#  [-0.2085377  -0.17240887        -inf        -inf        -inf        -inf
#   -0.17566407        -inf        -inf -0.19764871 -0.19849927        -inf
#          -inf        -inf]
#  [       -inf -0.14996462 -0.11418573        -inf        -inf -0.11952638
#          -inf -0.11178003        -inf        -inf -0.12021047 -0.13870098
#          -inf        -inf]
#  [       -inf        -inf -0.086943   -0.08427           -inf        -inf
#   -0.089616          -inf -0.1138917         -inf        -inf -0.09043928
#   -0.10317           -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.23589531        -inf        -inf        -inf        -inf -0.21442076
#          -inf        -inf        -inf        -inf -0.17501043        -inf
#          -inf        -inf]
#  [       -inf -0.16344113        -inf        -inf        -inf -0.15589968
#   -0.1467392         -inf        -inf -0.16135007        -inf -0.13739086
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12433297 -0.11656203        -inf        -inf -0.10138467        -inf
#   -0.1055757         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.21226924        -inf        -inf        -inf -0.25554534
#          -inf        -inf        -inf -0.21040755        -inf        -inf
#          -inf        -inf]
#  [-0.15668899        -inf -0.16347023        -inf        -inf -0.1595634
#   -0.1438098         -inf        -inf        -inf -0.15061478        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.1112187         -inf        -inf
#   -0.11957955 -0.12116226        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.1138917         -inf -0.12742383        -inf
#          -inf -0.089616   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.2085377  -0.1988997         -inf        -inf        -inf        -inf
#   -0.17566407        -inf        -inf -0.19764871 -0.19849927        -inf
#          -inf        -inf]
#  [       -inf -0.17936756 -0.14187731        -inf        -inf -0.11952638
#          -inf -0.17220806        -inf        -inf -0.12021047 -0.13870098
#          -inf        -inf]
#  [       -inf        -inf -0.086943   -0.111486          -inf        -inf
#   -0.089616          -inf -0.1138917         -inf        -inf -0.09043928
#   -0.10317           -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.23589531        -inf        -inf        -inf        -inf -0.21442076
#          -inf        -inf        -inf        -inf -0.17501043        -inf
#          -inf        -inf]
#  [       -inf -0.16344113        -inf        -inf        -inf -0.15589968
#   -0.1467392         -inf        -inf -0.16135007        -inf -0.13739086
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12433297 -0.11656203        -inf        -inf -0.10138467        -inf
#   -0.1055757         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.21226924        -inf        -inf        -inf -0.25554534
#          -inf        -inf        -inf -0.23669282        -inf        -inf
#          -inf        -inf]
#  [-0.15668899        -inf -0.16347023        -inf        -inf -0.1595634
#   -0.1438098         -inf        -inf        -inf -0.15061478        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.1112187         -inf        -inf
#   -0.11957955 -0.12116226        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.1138917         -inf -0.12742383        -inf
#          -inf -0.089616   -0.057             -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.2085377  -0.1988997         -inf        -inf        -inf        -inf
#   -0.17566407        -inf        -inf -0.19764871 -0.19849927        -inf
#          -inf        -inf]
#  [       -inf -0.17936756 -0.14187731        -inf        -inf -0.11952638
#          -inf -0.17220806        -inf        -inf -0.12021047 -0.13870098
#          -inf        -inf]
#  [       -inf        -inf -0.086943   -0.111486          -inf        -inf
#   -0.089616          -inf -0.1138917         -inf        -inf -0.09043928
#   -0.10317           -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03        0.        ]
#  [-0.23589531        -inf        -inf        -inf        -inf -0.21442076
#          -inf        -inf        -inf        -inf -0.22673643        -inf
#          -inf        -inf]
#  [       -inf -0.16344113        -inf        -inf        -inf -0.15589968
#   -0.1467392         -inf        -inf -0.19535989        -inf -0.16368886
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12433297 -0.11656203        -inf        -inf -0.15860695        -inf
#   -0.12501813        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.23527948        -inf        -inf        -inf -0.25554534
#          -inf        -inf        -inf -0.23669282        -inf        -inf
#          -inf        -inf]
#  [-0.15668899        -inf -0.16347023        -inf        -inf -0.1595634
#   -0.17126193        -inf        -inf        -inf -0.15061478        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.13573983        -inf        -inf
#   -0.11957955 -0.12116226        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.1138917         -inf -0.12742383        -inf
#          -inf -0.089616   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.2085377  -0.1988997         -inf        -inf        -inf        -inf
#   -0.1999985         -inf        -inf -0.19764871 -0.19849927        -inf
#          -inf        -inf]
#  [       -inf -0.17936756 -0.14187731        -inf        -inf -0.15496449
#          -inf -0.17220806        -inf        -inf -0.17881263 -0.16637052
#          -inf        -inf]
#  [       -inf        -inf -0.11925935 -0.111486          -inf        -inf
#   -0.089616          -inf -0.1138917         -inf        -inf -0.09043928
#   -0.10317           -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.23589531        -inf        -inf        -inf        -inf -0.21442076
#          -inf        -inf        -inf        -inf -0.22673643        -inf
#          -inf        -inf]
#  [       -inf -0.16344113        -inf        -inf        -inf -0.15589968
#   -0.1467392         -inf        -inf -0.19535989        -inf -0.16368886
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.12433297 -0.14351318        -inf        -inf -0.15860695        -inf
#   -0.12501813        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.28345065        -inf        -inf        -inf -0.27968188
#          -inf        -inf        -inf -0.2642512         -inf        -inf
#          -inf        -inf]
#  [-0.19631908        -inf -0.16347023        -inf        -inf -0.19340691
#   -0.17126193        -inf        -inf        -inf -0.18098737        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.13573983        -inf        -inf
#   -0.11957955 -0.12116226        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.1138917         -inf -0.12742383        -inf
#          -inf -0.089616   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.2085377  -0.2248065         -inf        -inf        -inf        -inf
#   -0.22646933        -inf        -inf -0.23123747 -0.22483001        -inf
#          -inf        -inf]
#  [       -inf -0.17936756 -0.20161048        -inf        -inf -0.18903526
#          -inf -0.19385924        -inf        -inf -0.20713656 -0.19204244
#          -inf        -inf]
#  [       -inf        -inf -0.11925935 -0.111486          -inf        -inf
#   -0.12599588        -inf -0.1138917         -inf        -inf -0.09043928
#   -0.10317           -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.26573837        -inf        -inf        -inf        -inf -0.24263011
#          -inf        -inf        -inf        -inf -0.22673643        -inf
#          -inf        -inf]
#  [       -inf -0.19260922        -inf        -inf        -inf -0.1848369
#   -0.17611113        -inf        -inf -0.19535989        -inf -0.21654945
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.18649023 -0.14351318        -inf        -inf -0.15860695        -inf
#   -0.1694038         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.28345065        -inf        -inf        -inf -0.30235892
#          -inf        -inf        -inf -0.29413418        -inf        -inf
#          -inf        -inf]
#  [-0.19631908        -inf -0.19504096        -inf        -inf -0.19340691
#   -0.20314794        -inf        -inf        -inf -0.21032364        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.13573983        -inf        -inf
#   -0.11957955 -0.12116226        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.1138917         -inf -0.12742383        -inf
#          -inf -0.089616   -0.0813            -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.2401044  -0.27607846        -inf        -inf        -inf        -inf
#   -0.25157979        -inf        -inf -0.26036957 -0.22483001        -inf
#          -inf        -inf]
#  [       -inf -0.20761436 -0.20161048        -inf        -inf -0.22302425
#          -inf -0.19385924        -inf        -inf -0.20713656 -0.217046
#          -inf        -inf]
#  [       -inf        -inf -0.11925935 -0.111486          -inf        -inf
#   -0.12599588        -inf -0.1138917         -inf        -inf -0.12709744
#   -0.122853          -inf]
#  [       -inf        -inf        -inf -0.03       -0.03              -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.29685304        -inf        -inf        -inf        -inf -0.24263011
#          -inf        -inf        -inf        -inf -0.22673643        -inf
#          -inf        -inf]
#  [       -inf -0.19260922        -inf        -inf        -inf -0.1848369
#   -0.20721451        -inf        -inf -0.19535989        -inf -0.21654945
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.18649023 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.1694038         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.30425287        -inf        -inf        -inf -0.30235892
#          -inf        -inf        -inf -0.31716767        -inf        -inf
#          -inf        -inf]
#  [-0.19631908        -inf -0.2441997         -inf        -inf -0.22632439
#   -0.20314794        -inf        -inf        -inf -0.21032364        -inf
#          -inf        -inf]
#  [       -inf -0.14703757        -inf -0.13573983        -inf        -inf
#   -0.15681366 -0.12116226        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.1138917         -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.27521324 -0.27607846        -inf        -inf        -inf        -inf
#   -0.25157979        -inf        -inf -0.26036957 -0.25064586        -inf
#          -inf        -inf]
#  [       -inf -0.20761436 -0.20161048        -inf        -inf -0.22302425
#          -inf -0.24233595        -inf        -inf -0.20713656 -0.217046
#          -inf        -inf]
#  [       -inf        -inf -0.11925935 -0.16528576        -inf        -inf
#   -0.12599588        -inf -0.13547253        -inf        -inf -0.12709744
#   -0.122853          -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.03              -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.29685304        -inf        -inf        -inf        -inf -0.24263011
#          -inf        -inf        -inf        -inf -0.2531311         -inf
#          -inf        -inf]
#  [       -inf -0.22265736        -inf        -inf        -inf -0.24695719
#   -0.20721451        -inf        -inf -0.19535989        -inf -0.21654945
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.18649023 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.1694038         -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.05997    -0.03              -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.32326317        -inf        -inf        -inf -0.35897194
#          -inf        -inf        -inf -0.33947128        -inf        -inf
#          -inf        -inf]
#  [-0.25362213        -inf -0.2441997         -inf        -inf -0.31167838
#   -0.26350458        -inf        -inf        -inf -0.2386319         -inf
#          -inf        -inf]
#  [       -inf -0.18315585        -inf -0.16344113        -inf        -inf
#   -0.15681366 -0.1819985         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.30571672        -inf        -inf        -inf        -inf
#   -0.32898931        -inf        -inf -0.29166438 -0.30439877        -inf
#          -inf        -inf]
#  [       -inf -0.29516426 -0.27283337        -inf        -inf -0.25649841
#          -inf -0.26068501        -inf        -inf -0.26467488 -0.24380393
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.16528576        -inf        -inf
#   -0.20124175        -inf -0.13547253        -inf        -inf -0.18992496
#   -0.1435377         -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.03       -0.03      ]
#  [-0.29685304        -inf        -inf        -inf        -inf -0.30574879
#          -inf        -inf        -inf        -inf -0.2531311         -inf
#          -inf        -inf]
#  [       -inf -0.25863654        -inf        -inf        -inf -0.24695719
#   -0.23699958        -inf        -inf -0.25316231        -inf -0.24166548
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.24675276 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.19956041        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.34456141        -inf        -inf        -inf -0.35897194
#          -inf        -inf        -inf -0.33947128        -inf        -inf
#          -inf        -inf]
#  [-0.25362213        -inf -0.2441997         -inf        -inf -0.31167838
#   -0.26350458        -inf        -inf        -inf -0.26983178        -inf
#          -inf        -inf]
#  [       -inf -0.18315585        -inf -0.16344113        -inf        -inf
#   -0.15681366 -0.1819985         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.30571672        -inf        -inf        -inf        -inf
#   -0.32898931        -inf        -inf -0.29166438 -0.30439877        -inf
#          -inf        -inf]
#  [       -inf -0.29516426 -0.27283337        -inf        -inf -0.25649841
#          -inf -0.27802829        -inf        -inf -0.26467488 -0.24380393
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.16528576        -inf        -inf
#   -0.20124175        -inf -0.18177335        -inf        -inf -0.18992496
#   -0.1435377         -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
#  [-0.29685304        -inf        -inf        -inf        -inf -0.30574879
#          -inf        -inf        -inf        -inf -0.28128095        -inf
#          -inf        -inf]
#  [       -inf -0.25863654        -inf        -inf        -inf -0.24695719
#   -0.26910744        -inf        -inf -0.28290606        -inf -0.24166548
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.24675276 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.19956041        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.34456141        -inf        -inf        -inf -0.35897194
#          -inf        -inf        -inf -0.39006544        -inf        -inf
#          -inf        -inf]
#  [-0.25362213        -inf -0.2441997         -inf        -inf -0.31167838
#   -0.26350458        -inf        -inf        -inf -0.26983178        -inf
#          -inf        -inf]
#  [       -inf -0.18315585        -inf -0.16344113        -inf        -inf
#   -0.15681366 -0.1819985         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.30571672        -inf        -inf        -inf        -inf
#   -0.32898931        -inf        -inf -0.29166438 -0.30439877        -inf
#          -inf        -inf]
#  [       -inf -0.29516426 -0.27283337        -inf        -inf -0.25649841
#          -inf -0.27802829        -inf        -inf -0.26467488 -0.24380393
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.16528576        -inf        -inf
#   -0.20124175        -inf -0.18177335        -inf        -inf -0.18992496
#   -0.1435377         -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
#  [-0.29685304        -inf        -inf        -inf        -inf -0.30574879
#          -inf        -inf        -inf        -inf -0.30707774        -inf
#          -inf        -inf]
#  [       -inf -0.25863654        -inf        -inf        -inf -0.24695719
#   -0.26910744        -inf        -inf -0.28290606        -inf -0.26725541
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.24675276 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.20960436        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.36428104        -inf        -inf        -inf -0.35897194
#          -inf        -inf        -inf -0.39006544        -inf        -inf
#          -inf        -inf]
#  [-0.25362213        -inf -0.26530429        -inf        -inf -0.31167838
#   -0.26350458        -inf        -inf        -inf -0.26983178        -inf
#          -inf        -inf]
#  [       -inf -0.18315585        -inf -0.16344113        -inf        -inf
#   -0.19526888 -0.1819985         -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.30571672        -inf        -inf        -inf        -inf
#   -0.32898931        -inf        -inf -0.29166438 -0.30439877        -inf
#          -inf        -inf]
#  [       -inf -0.29516426 -0.27283337        -inf        -inf -0.25649841
#          -inf -0.27802829        -inf        -inf -0.26467488 -0.27017437
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.16528576        -inf        -inf
#   -0.20124175        -inf -0.18177335        -inf        -inf -0.18992496
#   -0.1435377         -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
#  [-0.29685304        -inf        -inf        -inf        -inf -0.30574879
#          -inf        -inf        -inf        -inf -0.30707774        -inf
#          -inf        -inf]
#  [       -inf -0.25863654        -inf        -inf        -inf -0.24695719
#   -0.26910744        -inf        -inf -0.28290606        -inf -0.26725541
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.24675276 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.21864393        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.41061204        -inf        -inf        -inf -0.40862644
#          -inf        -inf        -inf -0.39006544        -inf        -inf
#          -inf        -inf]
#  [-0.29432374        -inf -0.28495453        -inf        -inf -0.31167838
#   -0.29254747        -inf        -inf        -inf -0.26983178        -inf
#          -inf        -inf]
#  [       -inf -0.18315585        -inf -0.22196777        -inf        -inf
#   -0.19526888 -0.23863041        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.33025364        -inf        -inf        -inf        -inf
#   -0.32898931        -inf        -inf -0.34862389 -0.35220853        -inf
#          -inf        -inf]
#  [       -inf -0.29516426 -0.27283337        -inf        -inf -0.32013008
#          -inf -0.27802829        -inf        -inf -0.29381241 -0.27017437
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.16528576        -inf        -inf
#   -0.20124175        -inf -0.20780625        -inf        -inf -0.18992496
#   -0.15918393        -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
#  [-0.32756843        -inf        -inf        -inf        -inf -0.33530939
#          -inf        -inf        -inf        -inf -0.3366391         -inf
#          -inf        -inf]
#  [       -inf -0.28903801        -inf        -inf        -inf -0.28252743
#   -0.29839951        -inf        -inf -0.28290606        -inf -0.26725541
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.24675276 -0.19151765        -inf        -inf -0.21624693        -inf
#   -0.21864393        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.42626418        -inf        -inf        -inf -0.46504663
#          -inf        -inf        -inf -0.41348817        -inf        -inf
#          -inf        -inf]
#  [-0.29432374        -inf -0.28495453        -inf        -inf -0.31167838
#   -0.29254747        -inf        -inf        -inf -0.29930689        -inf
#          -inf        -inf]
#  [       -inf -0.18315585        -inf -0.22196777        -inf        -inf
#   -0.19526888 -0.23863041        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.12742383        -inf
#          -inf -0.12192968 -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.33025364        -inf        -inf        -inf        -inf
#   -0.32898931        -inf        -inf -0.34862389 -0.35220853        -inf
#          -inf        -inf]
#  [       -inf -0.29516426 -0.27283337        -inf        -inf -0.32013008
#          -inf -0.27802829        -inf        -inf -0.29381241 -0.27017437
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.16528576        -inf        -inf
#   -0.20124175        -inf -0.20780625        -inf        -inf -0.18992496
#   -0.17326554        -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
#  [-0.3652656         -inf        -inf        -inf        -inf -0.33530939
#          -inf        -inf        -inf        -inf -0.3366391         -inf
#          -inf        -inf]
#  [       -inf -0.28903801        -inf        -inf        -inf -0.28252743
#   -0.29839951        -inf        -inf -0.28290606        -inf -0.29495839
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.27103773 -0.21812509        -inf        -inf -0.21624693        -inf
#   -0.21864393        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.47362618        -inf        -inf        -inf -0.46504663
#          -inf        -inf        -inf -0.46196285        -inf        -inf
#          -inf        -inf]
#  [-0.36301375        -inf -0.32346397        -inf        -inf -0.31167838
#   -0.34677669        -inf        -inf        -inf -0.3273839         -inf
#          -inf        -inf]
#  [       -inf -0.22380246        -inf -0.24184203        -inf        -inf
#   -0.2327525  -0.23863041        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.17453677        -inf
#          -inf -0.1561     -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.33569539 -0.35636633        -inf        -inf        -inf        -inf
#   -0.35531165        -inf        -inf -0.34862389 -0.35220853        -inf
#          -inf        -inf]
#  [       -inf -0.32385834 -0.29752484        -inf        -inf -0.32013008
#          -inf -0.27802829        -inf        -inf -0.29381241 -0.29456538
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.21822339        -inf        -inf
#   -0.20124175        -inf -0.20780625        -inf        -inf -0.18992496
#   -0.17326554        -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
#  [-0.3652656         -inf        -inf        -inf        -inf -0.3643484
#          -inf        -inf        -inf        -inf -0.38828697        -inf
#          -inf        -inf]
#  [       -inf -0.34702863        -inf        -inf        -inf -0.31696979
#   -0.29839951        -inf        -inf -0.31794272        -inf -0.29495839
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -0.27103773 -0.21812509        -inf        -inf -0.25259245        -inf
#   -0.21864393        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -0.09613545 -0.05997           -inf        -inf -0.05997
#          -inf  0.        ]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -0.48711973        -inf        -inf        -inf -0.54856729
#          -inf        -inf        -inf -0.48183705        -inf        -inf
#          -inf        -inf]
#  [-0.36301375        -inf -0.32346397        -inf        -inf -0.34502431
#   -0.34677669        -inf        -inf        -inf -0.3273839         -inf
#          -inf        -inf]
#  [       -inf -0.22380246        -inf -0.24184203        -inf        -inf
#   -0.2327525  -0.23863041        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -0.17395675        -inf -0.17453677        -inf
#          -inf -0.1561     -0.13306683        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.04071662        -inf        -inf
#          -inf        -inf -0.057             -inf        -inf        -inf
#          -inf -0.03      ]
#  [-0.37816547 -0.35636633        -inf        -inf        -inf        -inf
#   -0.35531165        -inf        -inf -0.3799228  -0.35220853        -inf
#          -inf        -inf]
#  [       -inf -0.32385834 -0.29752484        -inf        -inf -0.32013008
#          -inf -0.27802829        -inf        -inf -0.29381241 -0.29456538
#          -inf        -inf]
#  [       -inf        -inf -0.17766433 -0.21822339        -inf        -inf
#   -0.20124175        -inf -0.20780625        -inf        -inf -0.18992496
#   -0.18593898        -inf]
#  [       -inf        -inf        -inf -0.06587198 -0.086943          -inf
#          -inf -0.06947359        -inf        -inf        -inf        -inf
#   -0.057      -0.03      ]
# ...
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.55498438        -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.39146319        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.09618758
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80090944        -inf        -inf -1.83790649        -inf
#   -1.80084639        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.75559443        -inf        -inf        -inf -2.71642958
#          -inf        -inf        -inf -2.7361402         -inf        -inf
#          -inf        -inf]
#  [-2.3038575         -inf -2.30923277        -inf        -inf -2.29173242
#   -2.29727774        -inf        -inf        -inf -2.32256706        -inf
#          -inf        -inf]
#  [       -inf -1.86135962        -inf -1.75087778        -inf        -inf
#   -1.80897012 -1.80192246        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.37563886        -inf -1.31870532        -inf
#          -inf -1.37507619 -1.37241516        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.92625482        -inf        -inf
#          -inf        -inf -0.81218286        -inf        -inf        -inf
#          -inf -0.79955723]
#  [-2.44209704 -2.44012704        -inf        -inf        -inf        -inf
#   -2.43419138        -inf        -inf -2.44084954 -2.40805288        -inf
#          -inf        -inf]
#  [       -inf -2.09337918 -2.0227821         -inf        -inf -2.01272048
#          -inf -1.96893352        -inf        -inf -2.00422933 -2.04521215
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.55498438        -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.39146319        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.11996605
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80090944        -inf        -inf -1.83790649        -inf
#   -1.80259164        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.75559443        -inf        -inf        -inf -2.71318386
#          -inf        -inf        -inf -2.7361402         -inf        -inf
#          -inf        -inf]
#  [-2.3038575         -inf -2.30923277        -inf        -inf -2.29173242
#   -2.29727774        -inf        -inf        -inf -2.32256706        -inf
#          -inf        -inf]
#  [       -inf -1.86135962        -inf -1.75087778        -inf        -inf
#   -1.80897012 -1.80192246        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.37563886        -inf -1.31870532        -inf
#          -inf -1.37507619 -1.37241516        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.92625482        -inf        -inf
#          -inf        -inf -0.81218286        -inf        -inf        -inf
#          -inf -0.79955723]
#  [-2.44209704 -2.44012704        -inf        -inf        -inf        -inf
#   -2.43419138        -inf        -inf -2.44084954 -2.40712423        -inf
#          -inf        -inf]
#  [       -inf -2.09337918 -2.0227821         -inf        -inf -2.01272048
#          -inf -1.96893352        -inf        -inf -2.00422933 -2.04521215
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.5463265         -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.39146319        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.11625948
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80476195        -inf        -inf -1.83790649        -inf
#   -1.80259164        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.7369165         -inf        -inf        -inf -2.71318386
#          -inf        -inf        -inf -2.7361402         -inf        -inf
#          -inf        -inf]
#  [-2.3038575         -inf -2.30923277        -inf        -inf -2.33086447
#   -2.29727774        -inf        -inf        -inf -2.32256706        -inf
#          -inf        -inf]
#  [       -inf -1.86135962        -inf -1.75087778        -inf        -inf
#   -1.80897012 -1.80192246        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.37563886        -inf -1.31870532        -inf
#          -inf -1.37507619 -1.37241516        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.92625482        -inf        -inf
#          -inf        -inf -0.81218286        -inf        -inf        -inf
#          -inf -0.79955723]
#  [-2.44209704 -2.44012704        -inf        -inf        -inf        -inf
#   -2.43419138        -inf        -inf -2.44084954 -2.4059215         -inf
#          -inf        -inf]
#  [       -inf -2.09337918 -2.0227821         -inf        -inf -2.01272048
#          -inf -1.96893352        -inf        -inf -2.00422933 -2.04521215
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.5463265         -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.39146319        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.13818547
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80476195        -inf        -inf -1.83790649        -inf
#   -1.80416237        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.7369165         -inf        -inf        -inf -2.71318386
#          -inf        -inf        -inf -2.72928103        -inf        -inf
#          -inf        -inf]
#  [-2.3038575         -inf -2.30923277        -inf        -inf -2.33086447
#   -2.29727774        -inf        -inf        -inf -2.32256706        -inf
#          -inf        -inf]
#  [       -inf -1.86135962        -inf -1.75087778        -inf        -inf
#   -1.80897012 -1.80192246        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.37563886        -inf -1.31870532        -inf
#          -inf -1.37507619 -1.37241516        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.92625482        -inf        -inf
#          -inf        -inf -0.81218286        -inf        -inf        -inf
#          -inf -0.79955723]
#  [-2.44209704 -2.44012704        -inf        -inf        -inf        -inf
#   -2.43419138        -inf        -inf -2.44084954 -2.4059215         -inf
#          -inf        -inf]
#  [       -inf -2.09337918 -2.0227821         -inf        -inf -2.01272048
#          -inf -1.96893352        -inf        -inf -2.00422933 -2.04521215
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.5463265         -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.41884491        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.13129977
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80476195        -inf        -inf -1.89561149        -inf
#   -1.83095227        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.7369165         -inf        -inf        -inf -2.7100517
#          -inf        -inf        -inf -2.72928103        -inf        -inf
#          -inf        -inf]
#  [-2.3038575         -inf -2.30923277        -inf        -inf -2.33086447
#   -2.29727774        -inf        -inf        -inf -2.32256706        -inf
#          -inf        -inf]
#  [       -inf -1.86135962        -inf -1.75087778        -inf        -inf
#   -1.80897012 -1.80192246        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.37563886        -inf -1.31870532        -inf
#          -inf -1.37507619 -1.37241516        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.92625482        -inf        -inf
#          -inf        -inf -0.81218286        -inf        -inf        -inf
#          -inf -0.79955723]
#  [-2.44209704 -2.44012704        -inf        -inf        -inf        -inf
#   -2.43419138        -inf        -inf -2.44084954 -2.40632802        -inf
#          -inf        -inf]
#  [       -inf -2.09337918 -2.0227821         -inf        -inf -2.01272048
#          -inf -1.96893352        -inf        -inf -2.00422933 -2.04521215
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.53853441        -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.41884491        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.12684123
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80737207        -inf        -inf -1.89561149        -inf
#   -1.83095227        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
# [[       -inf -2.7369165         -inf        -inf        -inf -2.70727301
#          -inf        -inf        -inf -2.72928103        -inf        -inf
#          -inf        -inf]
#  [-2.3038575         -inf -2.30923277        -inf        -inf -2.33086447
#   -2.29727774        -inf        -inf        -inf -2.32256706        -inf
#          -inf        -inf]
#  [       -inf -1.86135962        -inf -1.75087778        -inf        -inf
#   -1.80897012 -1.80192246        -inf        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf -1.37563886        -inf -1.31870532        -inf
#          -inf -1.37507619 -1.37241516        -inf        -inf        -inf
#          -inf        -inf]
#  [       -inf        -inf        -inf -0.92625482        -inf        -inf
#          -inf        -inf -0.81218286        -inf        -inf        -inf
#          -inf -0.79955723]
#  [-2.44209704 -2.44012704        -inf        -inf        -inf        -inf
#   -2.43419138        -inf        -inf -2.44084954 -2.4062525         -inf
#          -inf        -inf]
#  [       -inf -2.09337918 -2.0227821         -inf        -inf -2.01272048
#          -inf -1.96893352        -inf        -inf -2.00422933 -2.04521215
#          -inf        -inf]
#  [       -inf        -inf -1.62938456 -1.64983127        -inf        -inf
#   -1.64696284        -inf -1.53152152        -inf        -inf -1.64741774
#   -1.62558707        -inf]
#  [       -inf        -inf        -inf -1.29495127 -1.23337377        -inf
#          -inf -1.23276724        -inf        -inf        -inf        -inf
#   -1.35795779 -1.18020764]
#  [-2.40791648        -inf        -inf        -inf        -inf -2.41254745
#          -inf        -inf        -inf        -inf -2.41884491        -inf
#          -inf        -inf]
#  [       -inf -2.16471757        -inf        -inf        -inf -2.15968362
#   -2.15388944        -inf        -inf -2.19522124        -inf -2.12308694
#          -inf        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#   -1.84234044 -1.80894977        -inf        -inf -1.89561149        -inf
#   -1.83095227        -inf]
#  [       -inf        -inf        -inf        -inf        -inf        -inf
#          -inf -1.54011916 -1.54693565        -inf        -inf -1.56379569
#          -inf -1.53363524]
#  [       -inf        -inf        -inf        -inf  0.                -inf
#          -inf        -inf  0.                -inf        -inf        -inf
#    0.                -inf]]
